# %% [markdown]
# [![Roboflow Notebooks](https://media.roboflow.com/notebooks/template/bannertest2-2.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672932710194)](https://github.com/roboflow/notebooks)
#
# # How to Train YOLOv5 on Custom Objects
#
# > **⚠️ Note:** This notebook has been updated since its creation. You may find it slightly different to the version shown in the accompanying [YouTube video](https://www.youtube.com/watch?v=x0ThXHbtqCQ) or [blog post](https://blog.roboflow.com/how-to-train-yolov5-on-a-custom-dataset/).
#
# YOLOv5 is a popular version of the YOLO (You Only Look Once) object detection and image segmentation model, released on November 22, 2022 by Ultralytics. The YOLOv5 model is designed to be fast, accurate, and easy to use, making it an excellent choice for a wide range of object detection and image segmentation tasks. It can be trained on large datasets and is capable of running on a variety of hardware platforms, from CPUs to GPUs.
#
# ## Disclaimer
#
# If you notice that our notebook behaves incorrectly - especially if you experience errors that prevent you from going through the tutorial - don't hesitate! Let us know and open an [issue](https://github.com/roboflow/notebooks/issues) on the Roboflow Notebooks repository.
#
# ## Accompanying Blog Post
#
# We recommend that you follow along in this notebook while reading the blog post on [how to train YOLOv5](https://blog.roboflow.ai/how-to-train-yolov5-on-a-custom-dataset/), concurrently.
#
# ## Steps Covered in this Tutorial
#
# In this tutorial, we will walk through the steps required to train YOLOv5 on your custom objects. We use the [Cash Counter](https://universe.roboflow.com/alex-hyams-cosqx/cash-counter/dataset/11) dataset, which is open source and free to use. You can also use this notebook on your own data.
#
# To train our detector we take the following steps:
#
# - Before you start
# - Install YOLOv5
# - Roboflow Universe
# - Prepare a Custom Dataset
# - Download custom YOLOv5 object detection data
# - Train Custom YOLOv5 Detector
# - Evaluate Custom YOLOv5 Detector Performance
# - Run Inference With Trained Weights
# - Deploy Model on Roboflow
# - Deploy Your Model to the Edge
#
# Let's get started!

# %% [markdown]
# ## Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Thu Oct 24 17:29:39 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0              46W / 400W |      2MiB / 40960MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# # Install YOLOv5

# %%
# clone YOLOv5 repository
# %cd /content/no
# !git clone https://github.com/ultralytics/yolov5
# Out:
# /content/no
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17516, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 17516 (delta 7), reused 0 (delta 0), pack-reused 17496 (from 4)
# Receiving objects: 100% (17516/17516), 16.62 MiB | 20.83 MiB/s, done.
# Resolving deltas: 100% (12002/12002), done.

# %%
# install dependencies as necessary
# !pip install -r /content/no/yolov5/requirements.txt
# !pip uninstall wandb -qy  # deprecated dependency
import torch

from IPython.display import Image, clear_output  # to display images

# clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Requirement already satisfied: gitpython>=3.1.30 in /usr/local/lib/python3.11/dist-packages (from -r /content/no/yolov5/requirements.txt (line 5)) (3.1.45)
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/lib/python3.11/dist-packages (from -r /content/no/yolov5/requirements.txt (line 6)) (3.10.0)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.11/dist-packages (from -r /content/no/yolov5/requirements.txt (line 7)) (2.0.2)
# Requirement already satisfied: opencv-python>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from -r /content/no/yolov5/requirements.txt (line 8)) (4.12.0.88)
# Requirement already satisfied: pillow>=10.3.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/no/yolov5/requirements.txt (line 9)) (11.3.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from -r /content/no/yolov5/requirements.txt (line 10)) (5.9.5)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from -r /content/no/yolov5/requirements.txt (line 11)) (6.0.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from -r /content/no/yolov5/requirements.txt (line 12)) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from -r /content/no/yolov5/requirements.txt (line 13)) (1.16.0)
# Requirement already satisfied: thop>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from -r /content/no/yolov5/requirements.txt (line 14)) (0.1.1.post2209072238)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/no/yolov5/requirements.txt (line 15)) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/no/yolov5/requirements.txt (line 16)) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from -r /content/no/yolov5/requirements.txt (line 17)) (4.67.1)
# Requirement already satisfied: ultralytics>=8.2.64 in /usr/local/lib/python3.11/dist-packages (from -r /content/no/yolov5/requirements.txt (line 18)) (8.3.170)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from -r /content/no/yolov5/requirements.txt (line 27)) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/no/yolov5/requirements.txt (line 28)) (0.13.2)
# Requirement already satisfied: setuptools>=70.0.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/no/yolov5/requirements.txt (line 42)) (75.2.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython>=3.1.30->-r /content/no/yolov5/requirements.txt (line 5)) (4.0.12)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r /content/no/yolov5/requirements.txt (line 6)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r /content/no/yolov5/requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r /content/no/yolov5/requirements.txt (line 6)) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r /content/no/yolov5/requirements.txt (line 6)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r /content/no/yolov5/requirements.txt (line 6)) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r /content/no/yolov5/requirements.txt (line 6)) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r /content/no/yolov5/requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->-r /content/no/yolov5/requirements.txt (line 12)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->-r /content/no/yolov5/requirements.txt (line 12)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->-r /content/no/yolov5/requirements.txt (line 12)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->-r /content/no/yolov5/requirements.txt (line 12)) (2025.7.14)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r /content/no/yolov5/requirements.txt (line 15)) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r /content/no/yolov5/requirements.txt (line 15)) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r /content/no/yolov5/requirements.txt (line 15)) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r /content/no/yolov5/requirements.txt (line 15)) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r /content/no/yolov5/requirements.txt (line 15)) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r /content/no/yolov5/requirements.txt (line 15)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r /content/no/yolov5/requirements.txt (line 15)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r /content/no/yolov5/requirements.txt (line 15)) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r /content/no/yolov5/requirements.txt (line 15)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r /content/no/yolov5/requirements.txt (line 15)) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r /content/no/yolov5/requirements.txt (line 15)) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r /content/no/yolov5/requirements.txt (line 15)) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r /content/no/yolov5/requirements.txt (line 15)) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r /content/no/yolov5/requirements.txt (line 15)) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r /content/no/yolov5/requirements.txt (line 15)) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r /content/no/yolov5/requirements.txt (line 15)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r /content/no/yolov5/requirements.txt (line 15)) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r /content/no/yolov5/requirements.txt (line 15)) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r /content/no/yolov5/requirements.txt (line 15)) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r /content/no/yolov5/requirements.txt (line 15)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->-r /content/no/yolov5/requirements.txt (line 15)) (1.3.0)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics>=8.2.64->-r /content/no/yolov5/requirements.txt (line 18)) (9.0.0)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics>=8.2.64->-r /content/no/yolov5/requirements.txt (line 18)) (2.0.14)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->-r /content/no/yolov5/requirements.txt (line 27)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->-r /content/no/yolov5/requirements.txt (line 27)) (2025.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r /content/no/yolov5/requirements.txt (line 5)) (5.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r /content/no/yolov5/requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->-r /content/no/yolov5/requirements.txt (line 15)) (3.0.2)
# WARNING: Skipping wandb as it is not installed.
# Setup complete. Using torch 2.6.0+cu124 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15095MB, multi_processor_count=40, uuid=b546eed0-0dbe-4a80-6ee4-878a829102e5, L2_cache_size=4MB)

# %% [markdown]
# ## Roboflow Universe
#
# Need data for your project? Before spending time on annotating, check out Roboflow Universe, a repository of more than 200,000 open-source datasets that you can use in your projects. You'll find datasets containing everything from annotated cracks in concrete to plant images with disease annotations.
#
#
# [![Roboflow Universe](https://media.roboflow.com/notebooks/template/uni-banner-frame.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672878480290)](https://universe.roboflow.com/)
#
# ## Preparing a custom dataset
#
# Building a custom dataset can be a painful process. It might take dozens or even hundreds of hours to collect images, label them, and export them in the proper format. Fortunately, Roboflow makes this process as straightforward and fast as possible. Let me show you how!
#
# ### Step 1: Creating project
#
# Before you start, you need to create a Roboflow [account](https://app.roboflow.com/login). Once you do that, you can create a new project in the Roboflow [dashboard](https://app.roboflow.com/). Keep in mind to choose the right project type. In our case, Object Detection.
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/creating-project.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1672929799852"
#   >
# </div>
#
# ### Step 2: Uploading images
#
# Next, add the data to your newly created project. You can do it via API or through our [web interface](https://docs.roboflow.com/adding-data/object-detection).
#
# If you drag and drop a directory with a dataset in a supported format, the Roboflow dashboard will automatically read the images and annotations together.
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/uploading-images.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1672929808290"
#   >
# </div>
#
# ### Step 3: Labeling
#
# If you only have images, you can label them in [Roboflow Annotate](https://docs.roboflow.com/annotate).
#
# <div align="center">
#   <img
#     width="640"
#     src="https://user-images.githubusercontent.com/26109316/210901980-04861efd-dfc0-4a01-9373-13a36b5e1df4.gif"
#   >
# </div>
#
# ### Step 4: Generate new dataset version
#
# Now that we have our images and annotations added, we can Generate a Dataset Version. When Generating a Version, you may elect to add preprocessing and augmentations. This step is completely optional, however, it can allow you to significantly improve the robustness of your model.
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/generate-new-version.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1673003597834"
#   >
# </div>
#
# ### Step 5: Exporting dataset
#
# Once the dataset version is generated, we have a hosted dataset we can load directly into our notebook for easy training. Click `Export` and select the `YOLO v5 PyTorch` dataset format.
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/export.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1672943313709"
#   >
# </div>

# %% [markdown]
# ## Step 6: Download a Dataset
#
# Run the code below to authenticate with Roboflow and download the dataset. Follow the link to generate an authentication token.
#
# Alternatively, provide an API key like so: `rf = Roboflow(api_key=...)`

# %% [markdown]
# > 🟢 **Tip:** The examples below work even if you use our non-custom dataset. However, you won't be able to deploy the model to Roboflow. To do that, create a custom dataset as described above or fork (copy) one into your [workspace](https://app.roboflow.com/) from [Universe](https://universe.roboflow.com/).

# %%
# %cd /content/no/yolov5
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ZsYvIGtwTxmYhXvsoXLC")
project = rf.workspace("qwqe-9j7ic").project("invoice-uubeo-itjhv")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# /content/no/yolov5
# Requirement already satisfied: roboflow in /usr/local/lib/python3.11/dist-packages (1.1.48)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from roboflow) (2025.7.14)
# Requirement already satisfied: idna==3.7 in /usr/local/lib/python3.11/dist-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in /usr/local/lib/python3.11/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.4.8)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from roboflow) (3.10.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.0.2)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /usr/local/lib/python3.11/dist-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from roboflow) (11.3.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.1.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.5.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (4.59.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (3.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->roboflow) (3.4.2)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Invoice-1 to yolov5pytorch:: 100%|██████████| 118864/118864 [00:01<00:00, 61763.51it/s]
# Extracting Dataset Version Zip to Invoice-1 in yolov5pytorch:: 100%|██████████| 1374/1374 [00:03<00:00, 377.31it/s]

# %% [markdown]
# # Train Custom YOLOv5 Detector
#
# ### Next, we'll fire off training!
#
#
# Here, we are able to pass a number of arguments:
# - **img:** define input image size
# - **batch:** determine batch size
# - **epochs:** define the number of training epochs. (Note: often, 3000+ are common here!)
# - **data:** set the path to our yaml file
# - **cfg:** specify our model configuration
# - **weights:** specify a custom path to weights. (Note: you can download weights from the Ultralytics Google Drive [folder](https://drive.google.com/open?id=1Drs_Aiu7xx6S-ix95f9kNsA6ueKRpN2J))
# - **name:** result names
# - **cache:** cache images for faster training

# %%
# train yolov5s on custom data for 25 epochs
# time its performance
# %%time
# %cd /content/no/yolov5/
# !python train.py \
  --img 416 \
  --batch 16 \
  --epochs 25 \
  --data {dataset.location}/data.yaml \
  --weights yolov5s.pt \
  --name yolov5s_results  \
  --cache
# Out:
# /content/no/yolov5
# 2025-07-29 09:19:47.466324: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753780787.489956   51552 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753780787.496028   51552 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# train: weights=yolov5s.pt, cfg=, data=/content/no/yolov5/Invoice-1/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=25, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=yolov5s_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-422-g2540fd4c Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
# 100% 14.1M/14.1M [00:00<00:00, 207MB/s]
#
# Overriding model.yaml nc=80 with nc=2
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     18879  models.yolo.Detect                      [2, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7025023 parameters, 7025023 gradients, 16.0 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# /content/no/yolov5/models/common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /content/no/yolov5/models/common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: 1 validation error for InitSchema
# size
#   Field required [type=missing, input_value={'scale': (0.8, 1.0), 'ra...: None, 'strict': False}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# train: Scanning /content/no/yolov5/Invoice-1/train/labels... 543 images, 0 backgrounds, 0 corrupt: 100% 543/543 [00:00<00:00, 856.22it/s]
# train: New cache created: /content/no/yolov5/Invoice-1/train/labels.cache
# train: Caching images (0.2GB ram): 100% 543/543 [00:03<00:00, 140.04it/s]
# val: Scanning /content/no/yolov5/Invoice-1/valid/labels... 43 images, 0 backgrounds, 0 corrupt: 100% 43/43 [00:00<00:00, 491.67it/s]
# val: New cache created: /content/no/yolov5/Invoice-1/valid/labels.cache
# val: Caching images (0.0GB ram): 100% 43/43 [00:00<00:00, 70.28it/s]
#
# AutoAnchor: 3.60 anchors/target, 0.961 Best Possible Recall (BPR). Anchors are a poor fit to dataset ⚠️, attempting to improve...
# AutoAnchor: WARNING ⚠️ Extremely small objects found: 3 of 4239 labels are <3 pixels in size
# AutoAnchor: Running kmeans for 9 anchors on 4236 points...
# AutoAnchor: Evolving anchors with Genetic Algorithm: fitness = 0.7700: 100% 1000/1000 [00:01<00:00, 794.65it/s]
# AutoAnchor: thr=0.25: 0.9965 best possible recall, 6.28 anchors past thr
# AutoAnchor: n=9, img_size=416, metric_all=0.386/0.770-mean/best, past_thr=0.480-mean: 37,10, 77,11, 47,31, 96,26, 80,42, 225,16, 120,57, 258,46, 258,90
# AutoAnchor: Done ✅ (optional: update model *.yaml to use these anchors in the future)
# Plotting labels to runs/train/yolov5s_results/labels.jpg...
# /content/no/yolov5/train.py:357: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=amp)
# Image sizes 416 train, 416 val
# Using 2 dataloader workers
# Logging results to runs/train/yolov5s_results
# Starting training for 25 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/34 [00:00<?, ?it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/24      1.56G     0.1217    0.07089    0.02938        253        416:   3% 1/34 [00:03<01:43,  3.13s/it]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/24      1.59G     0.1218    0.06798    0.02971        211        416:   6% 2/34 [00:03<00:47,  1.49s/it]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/24      1.59G     0.1216    0.06521    0.02963        208        416:   9% 3/34 [00:03<00:30,  1.02it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/24      1.59G     0.1214    0.06629    0.02963        223        416:  12% 4/34 [00:04<00:23,  1.30it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/24      1.59G     0.1212    0.06554    0.02948        197        416:  15% 5/34 [00:04<00:17,  1.65it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/24      1.59G     0.1211    0.06539    0.02949        209        416:  18% 6/34 [00:04<00:13,  2.11it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/24      1.59G      0.121    0.06592    0.02942        216        416:  21% 7/34 [00:05<00:10,  2.61it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/24      1.59G     0.1209     0.0654    0.02929        200        416:  24% 8/34 [00:05<00:07,  3.27it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/24      1.59G     0.1208    0.06622    0.02926        246        416:  26% 9/34 [00:05<00:06,  3.97it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/24      1.59G     0.1206    0.06796    0.02917        252        416:  29% 10/34 [00:05<00:05,  4.66it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/24      1.59G     0.1205    0.06913    0.02912        261        416:  32% 11/34 [00:05<00:04,  5.31it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/24      1.59G     0.1204    0.06969    0.02899        230        416:  35% 12/34 [00:05<00:03,  5.66it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/24      1.59G     0.1203    0.07013    0.02894        263        416:  38% 13/34 [00:05<00:03,  6.15it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/24      1.59G       0.12    0.07005    0.02883        191        416:  41% 14/34 [00:05<00:03,  6.56it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/24      1.59G     0.1197     0.0696    0.02874        177        416:  44% 15/34 [00:06<00:02,  6.84it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/24      1.59G     0.1195    0.06993    0.02865        215        416:  47% 16/34 [00:06<00:02,  7.06it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/24      1.59G     0.1192    0.07053    0.02857        235        416:  50% 17/34 [00:06<00:02,  7.25it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/24      1.59G      0.119    0.07161    0.02846        252        416:  53% 18/34 [00:06<00:02,  7.65it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/24      1.59G     0.1188    0.07187    0.02834        214        416:  56% 19/34 [00:06<00:01,  7.53it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/24      1.59G     0.1185    0.07142     0.0282        168        416:  59% 20/34 [00:06<00:01,  7.74it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/24      1.59G     0.1183    0.07227     0.0281        245        416:  62% 21/34 [00:06<00:01,  7.41it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/24      1.59G     0.1181    0.07183    0.02798        186        416:  65% 22/34 [00:06<00:01,  7.81it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/24      1.59G     0.1178    0.07247    0.02787        236        416:  68% 23/34 [00:07<00:01,  7.75it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/24      1.59G     0.1176    0.07269    0.02778        217        416:  71% 24/34 [00:07<00:01,  8.02it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/24      1.59G     0.1174    0.07337    0.02767        249        416:  74% 25/34 [00:07<00:01,  7.90it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/24      1.59G     0.1172    0.07389    0.02755        244        416:  76% 26/34 [00:07<00:00,  8.16it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/24      1.59G     0.1168    0.07389    0.02743        180        416:  79% 27/34 [00:07<00:00,  7.98it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/24      1.59G     0.1166    0.07417     0.0273        236        416:  82% 28/34 [00:07<00:00,  8.29it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/24      1.59G     0.1164    0.07466    0.02718        240        416:  85% 29/34 [00:07<00:00,  7.39it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/24      1.59G     0.1162     0.0751    0.02704        238        416:  88% 30/34 [00:08<00:00,  7.82it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/24      1.59G      0.116    0.07538    0.02689        238        416:  91% 31/34 [00:08<00:00,  7.70it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/24      1.59G     0.1158    0.07566    0.02677        234        416:  94% 32/34 [00:08<00:00,  8.05it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/24      1.59G     0.1156    0.07598    0.02666        250        416:  97% 33/34 [00:08<00:00,  7.77it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/24      1.59G     0.1153    0.07649    0.02649        221        416: 100% 34/34 [00:08<00:00,  3.96it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  2.73it/s]
#                    all         43        267    0.00791      0.412     0.0116    0.00289
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/34 [00:00<?, ?it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/24      1.95G     0.1092    0.08524    0.02208        255        416:   3% 1/34 [00:00<00:05,  5.94it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/24      1.95G     0.1075    0.08031    0.02189        194        416:   6% 2/34 [00:00<00:04,  7.27it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/24      1.95G     0.1064    0.07958    0.02174        190        416:   9% 3/34 [00:00<00:04,  7.21it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/24      1.95G      0.106    0.08302    0.02155        235        416:  12% 4/34 [00:00<00:03,  7.63it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/24      1.95G     0.1055    0.08284    0.02151        211        416:  15% 5/34 [00:00<00:03,  7.60it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/24      1.95G      0.105    0.08103    0.02147        184        416:  18% 6/34 [00:00<00:03,  8.05it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/24      1.95G     0.1049    0.08362    0.02121        283        416:  21% 7/34 [00:00<00:03,  7.85it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/24      1.95G     0.1043    0.08333    0.02098        205        416:  24% 8/34 [00:01<00:03,  8.06it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/24      1.95G      0.104    0.08396    0.02084        231        416:  26% 9/34 [00:01<00:03,  7.15it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/24      1.95G     0.1032    0.08325    0.02055        163        416:  29% 10/34 [00:01<00:03,  7.66it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/24      1.95G     0.1029    0.08403    0.02047        222        416:  32% 11/34 [00:01<00:03,  7.44it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/24      1.95G     0.1028    0.08439    0.02033        250        416:  35% 12/34 [00:01<00:02,  7.84it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/24      1.95G     0.1023    0.08451    0.02022        207        416:  38% 13/34 [00:01<00:02,  7.63it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/24      1.95G     0.1019    0.08422    0.02003        207        416:  41% 14/34 [00:01<00:02,  8.01it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/24      1.95G     0.1014    0.08387    0.01993        185        416:  44% 15/34 [00:01<00:02,  7.79it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/24      1.95G     0.1009    0.08428    0.01975        232        416:  47% 16/34 [00:02<00:02,  8.13it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/24      1.95G     0.1005    0.08402    0.01955        199        416:  50% 17/34 [00:02<00:02,  7.59it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/24      1.95G     0.1003    0.08389    0.01944        236        416:  53% 18/34 [00:02<00:02,  7.99it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/24      1.95G     0.1001    0.08498    0.01932        281        416:  56% 19/34 [00:02<00:01,  7.97it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/24      1.95G    0.09968    0.08551    0.01921        246        416:  59% 20/34 [00:02<00:01,  7.85it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/24      1.95G    0.09933    0.08559    0.01907        252        416:  62% 21/34 [00:02<00:01,  8.04it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/24      1.95G    0.09884     0.0852    0.01896        181        416:  65% 22/34 [00:02<00:01,  8.06it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/24      1.95G    0.09859    0.08523    0.01885        252        416:  68% 23/34 [00:02<00:01,  7.77it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/24      1.95G     0.0981    0.08528    0.01868        201        416:  71% 24/34 [00:03<00:01,  8.04it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/24      1.95G    0.09767    0.08543    0.01858        208        416:  74% 25/34 [00:03<00:01,  8.12it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/24      1.95G    0.09727    0.08508    0.01843        186        416:  76% 26/34 [00:03<00:01,  7.47it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/24      1.95G    0.09701    0.08529    0.01823        249        416:  79% 27/34 [00:03<00:00,  7.85it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/24      1.95G    0.09672    0.08483     0.0181        191        416:  82% 28/34 [00:03<00:00,  7.99it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/24      1.95G    0.09635    0.08479    0.01802        200        416:  85% 29/34 [00:03<00:00,  7.82it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/24      1.95G    0.09605    0.08527    0.01792        269        416:  88% 30/34 [00:03<00:00,  8.12it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/24      1.95G    0.09569    0.08495    0.01779        189        416:  91% 31/34 [00:03<00:00,  8.18it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/24      1.95G    0.09538    0.08499    0.01772        219        416:  94% 32/34 [00:04<00:00,  8.05it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/24      1.95G     0.0951    0.08469    0.01757        192        416:  97% 33/34 [00:04<00:00,  8.28it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/24      1.95G    0.09482    0.08528    0.01745        262        416: 100% 34/34 [00:04<00:00,  7.84it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  4.29it/s]
#                    all         43        267      0.153       0.51      0.176     0.0479
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/34 [00:00<?, ?it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/24      1.95G    0.08721    0.09469    0.01505        249        416:   3% 1/34 [00:00<00:06,  5.25it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/24      1.95G    0.08379    0.08552    0.01426        174        416:   6% 2/34 [00:00<00:05,  5.64it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/24      1.95G    0.08247    0.08544    0.01419        213        416:   9% 3/34 [00:00<00:07,  4.02it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/24      1.95G    0.08185    0.08237    0.01398        184        416:  12% 4/34 [00:00<00:06,  4.69it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/24      1.95G     0.0835    0.08337    0.01412        241        416:  15% 5/34 [00:01<00:05,  5.07it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/24      1.95G    0.08487    0.08413    0.01411        254        416:  18% 6/34 [00:01<00:07,  3.96it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/24      1.95G     0.0855    0.08439    0.01425        224        416:  21% 7/34 [00:01<00:07,  3.78it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/24      1.95G    0.08519    0.08272    0.01423        167        416:  24% 8/34 [00:01<00:05,  4.46it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/24      1.95G    0.08506    0.08257     0.0142        206        416:  26% 9/34 [00:02<00:06,  3.90it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/24      1.95G     0.0851    0.08248    0.01417        221        416:  29% 10/34 [00:02<00:05,  4.09it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/24      1.95G    0.08462    0.08267    0.01403        211        416:  32% 11/34 [00:02<00:04,  4.81it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/24      1.95G    0.08436    0.08301    0.01397        216        416:  35% 12/34 [00:02<00:04,  4.56it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/24      1.95G    0.08439    0.08302    0.01386        215        416:  38% 13/34 [00:02<00:04,  5.20it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/24      1.95G    0.08498    0.08347    0.01397        306        416:  41% 14/34 [00:02<00:03,  5.88it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/24      1.95G    0.08544    0.08365    0.01393        265        416:  44% 15/34 [00:03<00:02,  6.37it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/24      1.95G    0.08555    0.08254    0.01396        161        416:  47% 16/34 [00:03<00:02,  6.51it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/24      1.95G    0.08514    0.08282    0.01388        219        416:  50% 17/34 [00:03<00:02,  6.89it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/24      1.95G    0.08474    0.08306    0.01379        241        416:  53% 18/34 [00:03<00:02,  7.40it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/24      1.95G    0.08435    0.08339    0.01383        232        416:  56% 19/34 [00:03<00:01,  7.61it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/24      1.95G    0.08394    0.08341    0.01383        215        416:  59% 20/34 [00:03<00:01,  7.39it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/24      1.95G    0.08405    0.08326    0.01385        207        416:  62% 21/34 [00:03<00:01,  7.79it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/24      1.95G    0.08421    0.08281    0.01379        198        416:  65% 22/34 [00:03<00:01,  7.98it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/24      1.95G     0.0844    0.08207    0.01375        190        416:  68% 23/34 [00:04<00:01,  8.10it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/24      1.95G    0.08445    0.08159    0.01375        199        416:  71% 24/34 [00:04<00:01,  7.54it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/24      1.95G    0.08444    0.08182    0.01371        272        416:  74% 25/34 [00:04<00:01,  7.77it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/24      1.95G    0.08424    0.08184    0.01366        207        416:  76% 26/34 [00:04<00:00,  8.09it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/24      1.95G    0.08405     0.0815    0.01354        185        416:  79% 27/34 [00:04<00:00,  8.16it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/24      1.95G    0.08385     0.0814    0.01348        208        416:  82% 28/34 [00:04<00:00,  7.93it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/24      1.95G    0.08388    0.08145    0.01339        232        416:  85% 29/34 [00:04<00:00,  8.26it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/24      1.95G      0.084    0.08116    0.01336        238        416:  88% 30/34 [00:04<00:00,  8.35it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/24      1.95G    0.08403    0.08115    0.01335        225        416:  91% 31/34 [00:05<00:00,  8.26it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/24      1.95G    0.08403    0.08121    0.01329        225        416:  94% 32/34 [00:05<00:00,  7.63it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/24      1.95G    0.08399     0.0811    0.01328        231        416:  97% 33/34 [00:05<00:00,  7.95it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/24      1.95G    0.08396    0.08125    0.01323        231        416: 100% 34/34 [00:05<00:00,  6.20it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  4.56it/s]
#                    all         43        267      0.212      0.399      0.195     0.0633
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/34 [00:00<?, ?it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/24      1.95G    0.08147    0.07722     0.0122        233        416:   3% 1/34 [00:00<00:03,  8.28it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/24      1.95G     0.0815    0.07594    0.01292        200        416:   6% 2/34 [00:00<00:04,  7.91it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/24      1.95G    0.08101    0.07506    0.01304        203        416:   9% 3/34 [00:00<00:03,  8.38it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/24      1.95G    0.08065    0.07732    0.01251        239        416:  12% 4/34 [00:00<00:03,  8.40it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/24      1.95G     0.0801    0.07654    0.01247        190        416:  15% 5/34 [00:00<00:03,  8.38it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/24      1.95G     0.0799    0.07578    0.01211        183        416:  18% 6/34 [00:00<00:03,  8.07it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/24      1.95G    0.07875    0.07748    0.01216        236        416:  21% 7/34 [00:00<00:03,  8.09it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/24      1.95G    0.07817    0.07659    0.01253        183        416:  24% 8/34 [00:01<00:03,  7.64it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/24      1.95G    0.07788    0.07708    0.01225        224        416:  26% 9/34 [00:01<00:03,  8.01it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/24      1.95G    0.07739    0.07684    0.01212        207        416:  29% 10/34 [00:01<00:03,  7.53it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/24      1.95G     0.0774    0.07686    0.01204        203        416:  32% 11/34 [00:01<00:02,  7.93it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/24      1.95G    0.07754    0.07751    0.01194        257        416:  35% 12/34 [00:01<00:02,  8.16it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/24      1.95G    0.07745    0.07717    0.01184        191        416:  38% 13/34 [00:01<00:02,  8.09it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/24      1.95G    0.07759    0.07628    0.01188        166        416:  41% 14/34 [00:01<00:02,  7.81it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/24      1.95G    0.07755    0.07708    0.01197        255        416:  44% 15/34 [00:01<00:02,  8.12it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/24      1.95G    0.07746    0.07637    0.01189        195        416:  47% 16/34 [00:01<00:02,  8.14it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/24      1.95G    0.07742    0.07676     0.0118        229        416:  50% 17/34 [00:02<00:02,  6.21it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/24      1.95G    0.07743    0.07731    0.01177        244        416:  53% 18/34 [00:02<00:02,  5.52it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/24      1.95G    0.07773    0.07722    0.01171        234        416:  56% 19/34 [00:02<00:02,  6.19it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/24      1.95G    0.07785     0.0771    0.01162        221        416:  59% 20/34 [00:02<00:02,  6.49it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/24      1.95G    0.07798     0.0769     0.0116        229        416:  62% 21/34 [00:02<00:01,  6.70it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/24      1.95G    0.07822    0.07718    0.01155        268        416:  65% 22/34 [00:03<00:02,  4.56it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/24      1.95G    0.07781    0.07772    0.01144        237        416:  68% 23/34 [00:03<00:02,  5.36it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/24      1.95G    0.07739    0.07778    0.01147        210        416:  71% 24/34 [00:03<00:01,  6.00it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/24      1.95G    0.07697    0.07777    0.01148        200        416:  74% 25/34 [00:03<00:01,  6.45it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...
#   with torch.cuda.amp.autocast(amp):
#       23/24      2.08G    0.03013     0.0559   0.002146        188        416:  62% 21/34 [00:02<00:01,  7.86it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/24      2.08G    0.03009     0.0558   0.002113        207        416:  65% 22/34 [00:02<00:01,  7.20it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/24      2.08G    0.03006    0.05556   0.002127        177        416:  68% 23/34 [00:03<00:01,  7.27it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/24      2.08G     0.0301    0.05539    0.00215        174        416:  71% 24/34 [00:03<00:01,  7.67it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/24      2.08G    0.03008    0.05578   0.002162        251        416:  74% 25/34 [00:03<00:01,  7.91it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/24      2.08G    0.03008    0.05575   0.002198        216        416:  76% 26/34 [00:03<00:01,  7.34it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/24      2.08G    0.03008    0.05559   0.002194        185        416:  79% 27/34 [00:03<00:00,  7.26it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/24      2.08G    0.03002     0.0556   0.002217        205        416:  82% 28/34 [00:03<00:00,  7.69it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/24      2.08G    0.03009    0.05572   0.002251        209        416:  85% 29/34 [00:03<00:00,  7.91it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/24      2.08G    0.03002     0.0556   0.002269        210        416:  88% 30/34 [00:04<00:00,  7.75it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/24      2.08G    0.02987    0.05538   0.002283        180        416:  91% 31/34 [00:04<00:00,  8.07it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/24      2.08G    0.02992    0.05571   0.002293        253        416:  94% 32/34 [00:04<00:00,  8.11it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/24      2.08G    0.02999    0.05573   0.002268        250        416:  97% 33/34 [00:04<00:00,  7.74it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/24      2.08G    0.03003    0.05587   0.002253        230        416: 100% 34/34 [00:04<00:00,  7.49it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  5.58it/s]
#                    all         43        267      0.829      0.783      0.802      0.562
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/34 [00:00<?, ?it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/24      2.08G    0.03094    0.05981   0.001387        260        416:   3% 1/34 [00:00<00:03,  8.95it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/24      2.08G    0.02924    0.05441   0.001385        180        416:   6% 2/34 [00:00<00:03,  8.97it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/24      2.08G    0.02989    0.05443   0.001408        215        416:   9% 3/34 [00:00<00:04,  6.95it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/24      2.08G     0.0291    0.05364   0.001281        212        416:  12% 4/34 [00:00<00:04,  7.23it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/24      2.08G    0.02928    0.05217   0.001267        123        416:  15% 5/34 [00:00<00:03,  7.74it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/24      2.08G    0.02899    0.05154    0.00138        188        416:  18% 6/34 [00:00<00:03,  8.11it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/24      2.08G    0.02897     0.0528    0.00149        255        416:  21% 7/34 [00:00<00:03,  8.08it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/24      2.08G    0.02902    0.05334   0.001577        229        416:  24% 8/34 [00:01<00:03,  7.56it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/24      2.08G    0.02903    0.05379     0.0016        227        416:  26% 9/34 [00:01<00:03,  7.78it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/24      2.08G    0.02873    0.05325   0.001751        192        416:  29% 10/34 [00:01<00:03,  7.87it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/24      2.08G    0.02886    0.05343   0.001745        265        416:  32% 11/34 [00:01<00:02,  7.75it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/24      2.08G    0.02891    0.05323   0.001813        209        416:  35% 12/34 [00:01<00:03,  7.06it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/24      2.08G    0.02892    0.05379    0.00177        246        416:  38% 13/34 [00:01<00:02,  7.10it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/24      2.08G     0.0288    0.05346   0.001748        209        416:  41% 14/34 [00:01<00:02,  7.46it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/24      2.08G    0.02885    0.05331   0.001763        188        416:  44% 15/34 [00:01<00:02,  7.78it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/24      2.08G    0.02894    0.05378   0.001749        242        416:  47% 16/34 [00:02<00:02,  7.20it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/24      2.08G    0.02896    0.05374   0.001788        181        416:  50% 17/34 [00:02<00:02,  7.63it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/24      2.08G    0.02891    0.05366   0.001774        194        416:  53% 18/34 [00:02<00:02,  7.81it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/24      2.08G    0.02883    0.05372    0.00177        236        416:  56% 19/34 [00:02<00:02,  7.07it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/24      2.08G    0.02883    0.05359   0.001766        214        416:  59% 20/34 [00:02<00:01,  7.22it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/24      2.08G    0.02871    0.05366   0.001744        213        416:  62% 21/34 [00:02<00:01,  7.62it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/24      2.08G    0.02872    0.05372    0.00176        219        416:  65% 22/34 [00:02<00:01,  7.16it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/24      2.08G    0.02866    0.05394    0.00177        222        416:  68% 23/34 [00:03<00:01,  7.51it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/24      2.08G    0.02865    0.05376   0.001807        202        416:  71% 24/34 [00:03<00:01,  6.81it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/24      2.08G    0.02867    0.05389   0.001808        224        416:  74% 25/34 [00:03<00:01,  5.86it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/24      2.08G    0.02872    0.05391    0.00187        207        416:  76% 26/34 [00:03<00:01,  5.75it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/24      2.08G    0.02864    0.05386   0.001842        177        416:  79% 27/34 [00:03<00:01,  5.93it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/24      2.08G    0.02857    0.05393   0.001819        211        416:  82% 28/34 [00:04<00:01,  5.49it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/24      2.08G    0.02855    0.05413   0.001842        229        416:  85% 29/34 [00:04<00:01,  4.84it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/24      2.08G    0.02856    0.05423   0.001838        205        416:  88% 30/34 [00:04<00:00,  5.30it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/24      2.08G     0.0286    0.05435   0.001828        244        416:  91% 31/34 [00:04<00:00,  4.78it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/24      2.08G    0.02854    0.05406   0.001826        151        416:  94% 32/34 [00:04<00:00,  5.09it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/24      2.08G    0.02849    0.05377   0.001826        185        416:  97% 33/34 [00:05<00:00,  5.16it/s]/content/no/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/24      2.08G    0.02845    0.05366   0.001824        214        416: 100% 34/34 [00:05<00:00,  6.43it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  3.49it/s]
#                    all         43        267      0.833      0.775      0.809      0.569
#
# 25 epochs completed in 0.042 hours.
# Optimizer stripped from runs/train/yolov5s_results/weights/last.pt, 14.3MB
# Optimizer stripped from runs/train/yolov5s_results/weights/best.pt, 14.3MB
#
# Validating runs/train/yolov5s_results/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  2.09it/s]
#                    all         43        267      0.833      0.776      0.809      0.566
#              Paragraph         43        224      0.756      0.691      0.729      0.498
#                  Table         43         43      0.911       0.86      0.888      0.635
# Results saved to runs/train/yolov5s_results
# CPU times: user 1.5 s, sys: 220 ms, total: 1.72 s
# Wall time: 3min 1s

# %% [markdown]
# # Evaluate Custom YOLOv5 Detector Performance

# %% [markdown]
# You can view the training graphs associated with a training job in the `/content/yolov5/runs/train/yolov5s_results/results.png` folder.
#
# Training losses and performance metrics are also saved to Tensorboard and also to a logfile defined above with the **--name** flag when we train. In our case, we named this `yolov5s_results`.
#
# Note from Glenn: Partially completed `results.txt` files can be plotted with `from utils.utils import plot_results; plot_results()`.

# %%
from utils.plots import plot_results  # plot results.txt as results.png
Image(filename='/content/no/yolov5/runs/train/yolov5s_results/results.png', width=1000)

# %% [markdown]
# ### Curious? Visualize Our Training Data with Labels
#
# After training starts, view `train*.jpg` images to see training images, labels and augmentation effects.
#
# Note a mosaic dataloader is used for training (shown below), a new dataloading concept developed by Glenn Jocher and first featured in [YOLOv4](https://arxiv.org/abs/2004.10934).

# %%
Image(filename='/content/no/yolov5/runs/train/yolov5s_results/val_batch0_labels.jpg', width=900)

# %%
# print out an augmented training example
print("GROUND TRUTH AUGMENTED TRAINING DATA:")
Image(filename='/content/no/yolov5/runs/train/yolov5s_results/train_batch0.jpg', width=900)
# Out:
# GROUND TRUTH AUGMENTED TRAINING DATA:

# %% [markdown]
# # Run Inference With Trained Weights
#
# Next, we can run inference with a pretrained checkpoint on all images in the `test/images` folder to understand how our model performs on our test set.

# %%
# trained weights are saved by default in our weights folder
# %ls /content/no/yolov5/runs
# Out:
# train/

# %%
# %ls /content/no/yolov5/runs/train/yolov5s_results/weights
# Out:
# best.pt  last.pt

# %%
# %cd /content/yolov5/
# !python detect.py --weights /content/no/yolov5/runs/train/yolov5s_results/weights/best.pt --img 416 --conf 0.35 --source {dataset.location}/test/images/
# Out:
# /content/yolov5
# detect: weights=['/content/no/yolov5/runs/train/yolov5s_results/weights/best.pt'], source=/content/no/yolov5/Invoice-1/test/images/, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-422-g2540fd4c Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/95 /content/no/yolov5/Invoice-1/test/images/100_png.rf.ed4a729fc473a1a9c10855a0afc8413c.jpg: 416x320 8 Paragraphs, 1 Table, 28.9ms
# image 2/95 /content/no/yolov5/Invoice-1/test/images/106_png.rf.d36e99d6bb88f0bc8e53f1b3c1e39fe6.jpg: 416x320 7 Paragraphs, 1 Table, 6.1ms
# image 3/95 /content/no/yolov5/Invoice-1/test/images/10ed66fa-b113-4357-9b7c-22d084787ab8_jpeg.rf.6e04c5118eec4aa68994a8cb5804574c.jpg: 416x352 5 Paragraphs, 1 Table, 27.2ms
# image 4/95 /content/no/yolov5/Invoice-1/test/images/117_png.rf.80bf2f76f160c3cbd4b369dd02f36b59.jpg: 416x320 6 Paragraphs, 1 Table, 6.4ms
# image 5/95 /content/no/yolov5/Invoice-1/test/images/118_png.rf.a528687f06a5aeeab20f84302c22b5a5.jpg: 416x320 7 Paragraphs, 1 Table, 6.2ms
# image 6/95 /content/no/yolov5/Invoice-1/test/images/123_png.rf.ad6d2fd10887b3ffe2cdf269ca46c43b.jpg: 416x320 4 Paragraphs, 1 Table, 6.0ms
# image 7/95 /content/no/yolov5/Invoice-1/test/images/124_png.rf.15b0dd5c6bc7b2ad5ec5a34e44bae77f.jpg: 416x320 7 Paragraphs, 1 Table, 6.0ms
# image 8/95 /content/no/yolov5/Invoice-1/test/images/127_png.rf.84477033a8773572756272264ef69774.jpg: 416x320 5 Paragraphs, 1 Table, 6.0ms
# image 9/95 /content/no/yolov5/Invoice-1/test/images/128_png.rf.ba9637679fd8ca18e40c165b905de2e0.jpg: 416x320 9 Paragraphs, 2 Tables, 6.0ms
# image 10/95 /content/no/yolov5/Invoice-1/test/images/131f7202-9aae-4a9d-a928-e5e57f62b0ea_jpeg.rf.7ffc1d5ff0b9ab0b14379c13b3883c05.jpg: 416x320 1 Table, 5.9ms
# image 11/95 /content/no/yolov5/Invoice-1/test/images/137_png.rf.ae5e9e486af6444338c2ff0114d2bb95.jpg: 416x320 8 Paragraphs, 1 Table, 5.9ms
# image 12/95 /content/no/yolov5/Invoice-1/test/images/139_png.rf.91ed593bd6a5a1ad5836a77d646f4cea.jpg: 416x320 4 Paragraphs, 1 Table, 6.0ms
# image 13/95 /content/no/yolov5/Invoice-1/test/images/142_png.rf.26983360b6807a74a70f455f4e92699f.jpg: 416x320 7 Paragraphs, 2 Tables, 11.0ms
# image 14/95 /content/no/yolov5/Invoice-1/test/images/149_png.rf.df47622714f4d10f76cce9b1b5579191.jpg: 416x320 5 Paragraphs, 1 Table, 6.0ms
# image 15/95 /content/no/yolov5/Invoice-1/test/images/151_png.rf.83036ebcc59acb104f5ff580f4e9aa3c.jpg: 416x320 4 Paragraphs, 1 Table, 6.0ms
# image 16/95 /content/no/yolov5/Invoice-1/test/images/152_png.rf.cb1b2d85331571383ad908e99b55abc3.jpg: 416x320 5 Paragraphs, 1 Table, 6.0ms
# image 17/95 /content/no/yolov5/Invoice-1/test/images/153_png.rf.05761b71bdb6fca5ac5e41bab30568ac.jpg: 416x320 6 Paragraphs, 1 Table, 6.0ms
# image 18/95 /content/no/yolov5/Invoice-1/test/images/156_png.rf.9271d5f9ed94d388f5c0cb659a8677d0.jpg: 416x320 7 Paragraphs, 1 Table, 6.1ms
# image 19/95 /content/no/yolov5/Invoice-1/test/images/158_png.rf.fa15038e9f5e0c626c8f4f104d43f8bf.jpg: 416x320 6 Paragraphs, 1 Table, 6.0ms
# image 20/95 /content/no/yolov5/Invoice-1/test/images/171_png.rf.daea893fbf3deb3a15eec7a83f919e84.jpg: 416x320 8 Paragraphs, 1 Table, 6.0ms
# image 21/95 /content/no/yolov5/Invoice-1/test/images/174_png.rf.cecb88b66030960bdf1b25a108af60d3.jpg: 416x320 4 Paragraphs, 1 Table, 7.5ms
# image 22/95 /content/no/yolov5/Invoice-1/test/images/177_png.rf.e9ade6f4f818f9e83399ccf1a1cfa826.jpg: 416x320 7 Paragraphs, 1 Table, 6.0ms
# image 23/95 /content/no/yolov5/Invoice-1/test/images/181_png.rf.18f7d38b46fc9569d5e9d68e0bbc09a9.jpg: 416x320 7 Paragraphs, 1 Table, 6.0ms
# image 24/95 /content/no/yolov5/Invoice-1/test/images/183_png.rf.7ecf506d2c38eeac9986b5c4c7870ca5.jpg: 416x320 7 Paragraphs, 2 Tables, 6.3ms
# image 25/95 /content/no/yolov5/Invoice-1/test/images/184_png.rf.51f2d06fc4455ff1d8d6ab10b7c6a51b.jpg: 416x320 4 Paragraphs, 1 Table, 8.9ms
# image 26/95 /content/no/yolov5/Invoice-1/test/images/185_png.rf.13d302fa0e666c09c48306e64ee9bf1f.jpg: 416x320 7 Paragraphs, 1 Table, 6.0ms
# image 27/95 /content/no/yolov5/Invoice-1/test/images/186_png.rf.18c405635f3fdd5b21437a70e61ebd66.jpg: 416x320 5 Paragraphs, 1 Table, 6.2ms
# image 28/95 /content/no/yolov5/Invoice-1/test/images/187_png.rf.5e82167905d53e67d8ce1ea375d62f2e.jpg: 416x320 6 Paragraphs, 1 Table, 6.5ms
# image 29/95 /content/no/yolov5/Invoice-1/test/images/188_png.rf.e902008cec3ca2ebe0ab76f5e13192ad.jpg: 416x320 7 Paragraphs, 1 Table, 6.0ms
# image 30/95 /content/no/yolov5/Invoice-1/test/images/189_png.rf.c15b0d1b622e4896ac681e7fd3d99881.jpg: 416x320 8 Paragraphs, 1 Table, 6.2ms
# image 31/95 /content/no/yolov5/Invoice-1/test/images/190_png.rf.ae935a07ff23f538279afa22fd7cdfec.jpg: 416x320 6 Paragraphs, 1 Table, 6.0ms
# image 32/95 /content/no/yolov5/Invoice-1/test/images/191_png.rf.6e4c38ac2ae60245f05e0c6f15e1b77b.jpg: 416x320 6 Paragraphs, 1 Table, 6.0ms
# image 33/95 /content/no/yolov5/Invoice-1/test/images/195_png.rf.f82719ca81f539ec6cda174f710efd2d.jpg: 416x320 6 Paragraphs, 1 Table, 6.7ms
# image 34/95 /content/no/yolov5/Invoice-1/test/images/202_png.rf.e680981921019eab6297e01e12d1cfbb.jpg: 416x320 4 Paragraphs, 1 Table, 6.0ms
# image 35/95 /content/no/yolov5/Invoice-1/test/images/205_png.rf.9cc69ebe2964a12fd29cae1d4f3b98e2.jpg: 416x320 8 Paragraphs, 1 Table, 6.0ms
# image 36/95 /content/no/yolov5/Invoice-1/test/images/208_png.rf.7d0c094d4aef5428e7792632c1381147.jpg: 416x320 5 Paragraphs, 1 Table, 5.9ms
# image 37/95 /content/no/yolov5/Invoice-1/test/images/209_png.rf.2c0350e8da82c7b076f0e03546b2c847.jpg: 416x320 7 Paragraphs, 1 Table, 5.9ms
# image 38/95 /content/no/yolov5/Invoice-1/test/images/218_png.rf.3498104314325c6655f117e6346cc987.jpg: 416x320 7 Paragraphs, 1 Table, 5.9ms
# image 39/95 /content/no/yolov5/Invoice-1/test/images/220_png.rf.8dd81244eae5530bff06cad7ec447285.jpg: 416x320 7 Paragraphs, 1 Table, 5.9ms
# image 40/95 /content/no/yolov5/Invoice-1/test/images/223_png.rf.e140303176685c8f2cb6f21391c2817e.jpg: 416x320 11 Paragraphs, 1 Table, 5.9ms
# image 41/95 /content/no/yolov5/Invoice-1/test/images/225_png.rf.5ff9c928fe25cd781ee1b8b77a298854.jpg: 416x320 7 Paragraphs, 1 Table, 7.4ms
# image 42/95 /content/no/yolov5/Invoice-1/test/images/229_png.rf.b4ede763579b9e86af6b8aea8d84d7d3.jpg: 416x320 7 Paragraphs, 1 Table, 9.8ms
# image 43/95 /content/no/yolov5/Invoice-1/test/images/240_jpg.rf.d436faf2b0a77fce8e08ccfc47029854.jpg: 416x320 13 Paragraphs, 1 Table, 6.0ms
# image 44/95 /content/no/yolov5/Invoice-1/test/images/242_jpg.rf.d69c71bab704d2c85d948e400a18c93d.jpg: 416x320 11 Paragraphs, 1 Table, 6.3ms
# image 45/95 /content/no/yolov5/Invoice-1/test/images/276_png.rf.af52de7156023da0ba0b44cd7a7fa06d.jpg: 416x352 5 Paragraphs, 1 Table, 6.7ms
# image 46/95 /content/no/yolov5/Invoice-1/test/images/282_png.rf.b4527d98fac9ed37b99ded799f099ac9.jpg: 416x320 5 Paragraphs, 1 Table, 6.3ms
# image 47/95 /content/no/yolov5/Invoice-1/test/images/293_png.rf.b0c3c938d576deee259cf83be7d2d846.jpg: 416x352 8 Paragraphs, 1 Table, 6.1ms
# image 48/95 /content/no/yolov5/Invoice-1/test/images/295_png.rf.b0ecf154c7d168f3336fb2a1e8842a60.jpg: 416x352 8 Paragraphs, 1 Table, 6.0ms
# image 49/95 /content/no/yolov5/Invoice-1/test/images/29_jpg.rf.bb5c20f03ebc39f2181ef0d27402fcbe.jpg: 416x384 10 Paragraphs, 2 Tables, 27.9ms
# image 50/95 /content/no/yolov5/Invoice-1/test/images/2dd1937e-8552-4867-a70c-3db47d5246e6_png.rf.c79fec68c652f761b71f5e27bb48574c.jpg: 256x416 3 Paragraphs, 1 Table, 33.8ms
# image 51/95 /content/no/yolov5/Invoice-1/test/images/301_jpg.rf.86d8a77607c29b1ee379c5d17f8d4661.jpg: 416x320 9 Paragraphs, 1 Table, 6.5ms
# image 52/95 /content/no/yolov5/Invoice-1/test/images/319ae2a5-5ed5-482c-af1e-186351c11921_jpg.rf.ac63f1750c6af2d2283a66d6e40ab3a3.jpg: 416x352 6 Paragraphs, 1 Table, 9.5ms
# image 53/95 /content/no/yolov5/Invoice-1/test/images/334_jpg.rf.9a5f20d0779a0c4599c4aec20c5902ba.jpg: 416x320 8 Paragraphs, 1 Table, 7.3ms
# image 54/95 /content/no/yolov5/Invoice-1/test/images/338c292c-be82-4f44-8b56-21014f4a0cd1_jpg.rf.7ad76513f296e2eb10c8443649e498de.jpg: 416x320 10 Paragraphs, 2 Tables, 6.0ms
# image 55/95 /content/no/yolov5/Invoice-1/test/images/33_jpg.rf.4393dab1086da64bc8fd8cc4ba6e04a1.jpg: 416x320 9 Paragraphs, 1 Table, 6.5ms
# image 56/95 /content/no/yolov5/Invoice-1/test/images/371_jpg.rf.51894c419806f67878242a5373c17ffe.jpg: 416x320 1 Table, 6.5ms
# image 57/95 /content/no/yolov5/Invoice-1/test/images/385_jpg.rf.d80ea8239c282feebb811e1e39b0ae27.jpg: 416x320 2 Paragraphs, 6.2ms
# image 58/95 /content/no/yolov5/Invoice-1/test/images/399_jpg.rf.290ec8ef9e034a1480f003887477d438.jpg: 416x352 9 Paragraphs, 1 Table, 6.7ms
# image 59/95 /content/no/yolov5/Invoice-1/test/images/39_png.rf.38b197c46fdbd24bf864fc7a4b9918ef.jpg: 416x352 8 Paragraphs, 1 Table, 6.3ms
# image 60/95 /content/no/yolov5/Invoice-1/test/images/405_png.rf.b7dfabe2b88db7288ecccac6d4ca3a96.jpg: 416x416 10 Paragraphs, 1 Table, 7.2ms
# image 61/95 /content/no/yolov5/Invoice-1/test/images/406_jpg.rf.eedc2328d65b94dd95a21ab84f994698.jpg: 320x416 3 Paragraphs, 2 Tables, 29.1ms
# image 62/95 /content/no/yolov5/Invoice-1/test/images/411_jpg.rf.d370717e92a925557e87bad33e75009f.jpg: 416x320 11 Paragraphs, 1 Table, 6.1ms
# image 63/95 /content/no/yolov5/Invoice-1/test/images/432_png.rf.083f6baf4f06a4158c220ef4d4ceb188.jpg: 320x416 2 Paragraphs, 1 Table, 6.2ms
# image 64/95 /content/no/yolov5/Invoice-1/test/images/433_png.rf.741243c48ca5bec5dc09569ef7f5e82b.jpg: 320x416 8 Paragraphs, 1 Table, 5.9ms
# image 65/95 /content/no/yolov5/Invoice-1/test/images/439_png.rf.2a70e19d903117a690718da7db3e62d8.jpg: 384x416 6 Paragraphs, 1 Table, 28.0ms
# image 66/95 /content/no/yolov5/Invoice-1/test/images/43_png.rf.bb186ae82a83e6fa2d724ce911e34011.jpg: 416x320 7 Paragraphs, 1 Table, 8.1ms
# image 67/95 /content/no/yolov5/Invoice-1/test/images/453_jpg.rf.4093d0fb18f21adb7a034a16b13198ed.jpg: 416x320 18 Paragraphs, 6.0ms
# image 68/95 /content/no/yolov5/Invoice-1/test/images/457c3f7b-9c0b-41c1-b9d2-ece26cc55da7_jpg.rf.7e2d79835ecd2c3e0e9dc5094e55d477.jpg: 352x416 6 Paragraphs, 1 Table, 28.6ms
# image 69/95 /content/no/yolov5/Invoice-1/test/images/467_jpg.rf.762284ce2327575f5bc93e819a6b3691.jpg: 416x352 12 Paragraphs, 1 Table, 6.2ms
# image 70/95 /content/no/yolov5/Invoice-1/test/images/470_jpg.rf.a89cb01d8e25fcf6ab03e0f085b83633.jpg: 416x320 8 Paragraphs, 1 Table, 6.3ms
# image 71/95 /content/no/yolov5/Invoice-1/test/images/479_png.rf.3ebd8f35bf72023771bdb5b438205b76.jpg: 288x416 4 Paragraphs, 1 Table, 29.3ms
# image 72/95 /content/no/yolov5/Invoice-1/test/images/49_png.rf.a9fabde659421a457e9ba18a2fa51656.jpg: 416x320 7 Paragraphs, 1 Table, 6.6ms
# image 73/95 /content/no/yolov5/Invoice-1/test/images/4ea82b85-8047-4f49-a6a1-e6de8af5ce0d_png.rf.dcad70939154a8a5a2f4af64de1f34e4.jpg: 288x416 7 Paragraphs, 1 Table, 8.0ms
# image 74/95 /content/no/yolov5/Invoice-1/test/images/500_png.rf.dc2235cc09e174d6b6935e905ec0fc65.jpg: 416x288 14 Paragraphs, 2 Tables, 44.4ms
# image 75/95 /content/no/yolov5/Invoice-1/test/images/506_jpg.rf.135b08b50cf7ae8c869e6989e4d2f248.jpg: 416x320 6 Paragraphs, 1 Table, 7.9ms
# image 76/95 /content/no/yolov5/Invoice-1/test/images/507_jpg.rf.b05575c55d61ffdcb2e1b4bbd2e290c8.jpg: 416x320 6 Paragraphs, 1 Table, 5.9ms
# image 77/95 /content/no/yolov5/Invoice-1/test/images/50_png.rf.fe855646059f7ec98ad9f9852d2948c7.jpg: 416x320 8 Paragraphs, 1 Table, 5.9ms
# image 78/95 /content/no/yolov5/Invoice-1/test/images/515_jpg.rf.2b65d4c20844eb11d5c2b039285d7783.jpg: 416x384 5 Paragraphs, 2 Tables, 6.5ms
# image 79/95 /content/no/yolov5/Invoice-1/test/images/517_jpg.rf.18604165082d3f0009e6ecea0a99bd21.jpg: 416x384 10 Paragraphs, 1 Table, 6.4ms
# image 80/95 /content/no/yolov5/Invoice-1/test/images/531_jpg.rf.30264866bc750b2f264a7ea711bc4511.jpg: 416x352 5 Paragraphs, 1 Table, 6.5ms
# image 81/95 /content/no/yolov5/Invoice-1/test/images/536_png.rf.0b99daccdbd36ef9dd56fc53359d5c7d.jpg: 416x384 12 Paragraphs, 1 Table, 6.9ms
# image 82/95 /content/no/yolov5/Invoice-1/test/images/539_png.rf.9589389128aaaeba2d505cc6fd0f4079.jpg: 416x352 9 Paragraphs, 1 Table, 6.2ms
# image 83/95 /content/no/yolov5/Invoice-1/test/images/53_png.rf.6785e574737033133d432eee0394cf77.jpg: 416x320 6 Paragraphs, 1 Table, 6.3ms
# image 84/95 /content/no/yolov5/Invoice-1/test/images/546_jpg.rf.43c594c173a3d357c01c33a032406e23.jpg: 416x352 8 Paragraphs, 1 Table, 6.1ms
# image 85/95 /content/no/yolov5/Invoice-1/test/images/54_png.rf.03e5cc468d2452a8d332a879af0e4a0e.jpg: 416x320 7 Paragraphs, 1 Table, 6.1ms
# image 86/95 /content/no/yolov5/Invoice-1/test/images/55_png.rf.50d02720b8c6691db4fda76f111d4815.jpg: 416x320 6 Paragraphs, 1 Table, 5.9ms
# image 87/95 /content/no/yolov5/Invoice-1/test/images/567_jpg.rf.4a320a4df9195f277012fed78eec2560.jpg: 416x320 5 Paragraphs, 1 Table, 5.9ms
# image 88/95 /content/no/yolov5/Invoice-1/test/images/58_png.rf.3759be057b75b7b3a37fcb84ef3d983a.jpg: 416x320 7 Paragraphs, 1 Table, 5.9ms
# image 89/95 /content/no/yolov5/Invoice-1/test/images/669_jpg.rf.30bf2c5d2d63cad0d43a4b587e9378e8.jpg: 416x352 2 Paragraphs, 1 Table, 8.4ms
# image 90/95 /content/no/yolov5/Invoice-1/test/images/989e721d-8fca-49e2-b4b0-ffb2f79cd176_png.rf.d8ea50d6f03e9a866a2ddd2a2b930f6f.jpg: 416x352 10 Paragraphs, 2 Tables, 6.1ms
# image 91/95 /content/no/yolov5/Invoice-1/test/images/a7ab822c-abae-4ce9-adf3-294f349952a7_png.rf.54c6ecc95875f62c883412cca57c9ae5.jpg: 416x320 12 Paragraphs, 1 Table, 8.4ms
# image 92/95 /content/no/yolov5/Invoice-1/test/images/ab6dee1e-6199-4ee5-bb66-146608363207_jpg.rf.7c38535cc2704d7d69e92acfe39aee1d.jpg: 416x352 1 Table, 7.0ms
# image 93/95 /content/no/yolov5/Invoice-1/test/images/de07dc70-921f-47e2-ab79-80a192eddec3_jpg.rf.065a9811e4068aa2ea396533aacdbe2a.jpg: 416x384 7 Paragraphs, 1 Table, 6.5ms
# image 94/95 /content/no/yolov5/Invoice-1/test/images/f0c1e56f-41e2-40a1-a6ac-8b29b59d82ee_jpg.rf.169dec06c6c3c3012e1bb35581e8c4a4.jpg: 416x320 9 Paragraphs, 2 Tables, 6.3ms
# image 95/95 /content/no/yolov5/Invoice-1/test/images/fee4caf7-96ba-41db-ae55-90be82280b3a_jpg.rf.77ac4c4bb271b3bfdc4e00c6d11fd80b.jpg: 416x352 19 Paragraphs, 6.6ms
# Speed: 0.3ms pre-process, 8.8ms inference, 3.0ms NMS per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/exp2

# %%
import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/no/yolov5/runs/detect/exp2/*.jpg')[:10]: #assuming JPG
    display(Image(filename=imageName))

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="ZsYvIGtwTxmYhXvsoXLC")
project = rf.workspace("qwqe-9j7ic").project("invoice-uubeo-itjhv")
version = project.version(1)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# ## Deploy Model on Roboflow
#
# Once you have finished training your YOLOv5 model, you’ll have a set of trained weights ready for use. These weights will be in the `/content/yolov5/runs/train/yolov5s_results/` folder of your project. You can upload your model weights to Roboflow Deploy to use your trained weights on our infinitely scalable infrastructure.
#
# The `.deploy()` function in the [Roboflow pip package](https://docs.roboflow.com/python) now supports uploading YOLOv5 weights.
#
# **Before you run this code, make sure you create a new Version in the Roboflow dashboard following the instructions we covered earlier. Fill in your project name, workspace, and version number below.**
#
# To upload model weights, add the following code to the “Inference with Custom Model” section in the aforementioned notebook:

# %%
import torch
from matplotlib import pyplot as plt
import cv2

# Load trained YOLOv5 model from local path
model = torch.hub.load('/content/no/yolov5', 'custom', path='/content/no/yolov5/runs/train/yolov5s_results/weights/best.pt', source='local')

# Optional: Set confidence threshold
model.conf = 0.35

# Run inference on a test image
image_path = '/content/no/yolov5/Invoice-1/test/images/100_png.rf.ed4a729fc473a1a9c10855a0afc8413c.jpg'
results = model(image_path)

# Show detection result
results.print()             # Print results to console
results.show()              # Display image with bounding boxes
results.save()              # Save image with boxes to runs/detect/exp/
# Out:
# YOLOv5 🚀 v7.0-422-g2540fd4c Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...
# `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# image 1/1: 1061x750 8 Paragraphs, 1 Table
# Speed: 13.9ms pre-process, 42.4ms inference, 168.0ms NMS per image at shape (1, 3, 640, 480)
# <PIL.Image.Image image mode=RGB size=750x1061>
# Saved 1 image to runs/detect/exp3

# %%
import torch
import os
import random

# === Load your trained local YOLOv5 model ===
model = torch.hub.load('/content/no/yolov5', 'custom', path='/content/no/yolov5/runs/train/yolov5s_results/weights/best.pt', source='local')

# === Choose random test image ===
test_set_loc = "/content/no/yolov5/Invoice-1/test/images"
random_test_image = random.choice(os.listdir(test_set_loc))
image_path = os.path.join(test_set_loc, random_test_image)

print("Running inference on:", image_path)

# === Run inference ===
results = model(image_path)

# === Print and save results ===
results.print()
results.save()  # Saves output to 'runs/detect/exp'

# === Optional: Extract detections programmatically ===
for *box, conf, cls in results.xyxy[0]:
    x1, y1, x2, y2 = map(int, box)
    class_name = model.names[int(cls)]
    print(f"{class_name}: ({x1},{y1}) to ({x2},{y2}) with confidence {conf:.2f}")
# Out:
# YOLOv5 🚀 v7.0-422-g2540fd4c Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...
# `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# image 1/1: 2048x1446 15 Paragraphs, 1 Table
# Speed: 25.6ms pre-process, 7.3ms inference, 2.8ms NMS per image at shape (1, 3, 640, 480)
# Saved 1 image to runs/detect/exp4
# Running inference on: /content/no/yolov5/Invoice-1/test/images/334_jpg.rf.9a5f20d0779a0c4599c4aec20c5902ba.jpg
# Paragraph: (109,1640) to (1188,1804) with confidence 0.88
# Paragraph: (822,301) to (1169,589) with confidence 0.82
# Table: (44,900) to (1381,1181) with confidence 0.78
# Paragraph: (44,728) to (1375,825) with confidence 0.73
# Paragraph: (110,86) to (354,145) with confidence 0.71
# Paragraph: (116,593) to (443,679) with confidence 0.68
# Paragraph: (101,1409) to (322,1436) with confidence 0.66
# Paragraph: (841,104) to (1359,255) with confidence 0.63
# Paragraph: (98,1967) to (717,2016) with confidence 0.63
# Paragraph: (823,113) to (1045,227) with confidence 0.60
# Paragraph: (615,1408) to (829,1432) with confidence 0.59
# Paragraph: (1127,1963) to (1352,2020) with confidence 0.55
# Paragraph: (104,1629) to (344,1657) with confidence 0.52
# Paragraph: (592,1269) to (1342,1336) with confidence 0.31
# Paragraph: (106,389) to (241,455) with confidence 0.26
# Paragraph: (100,310) to (416,350) with confidence 0.26

# %% [markdown]
# # Deploy Your Model to the Edge
#
# In addition to using the Roboflow hosted API for deployment, you can use [Roboflow Inference](https://inference.roboflow.com), an open source inference solution that has powered millions of API calls in production environments. Inference works with CPU and GPU, giving you immediate access to a range of devices, from the NVIDIA Jetson to TRT-compatible devices to ARM CPU devices.
#
# With Roboflow Inference, you can self-host and deploy your model on-device. You can deploy applications using the [Inference Docker containers](https://inference.roboflow.com/quickstart/docker/) or the pip package.
#
# For example, to install Inference on a device with an NVIDIA GPU, we can use:
#
# ```
# docker pull roboflow/roboflow-inference-server-gpu
# ```
#
# Then we can run inference via HTTP:
#
# ```python
# import requests
#
# workspace_id = ""
# model_id = ""
# image_url = ""
# confidence = 0.75
# api_key = ""
# iou_threshold = 0.5
#
# infer_payload = {
#     "image": {
#         "type": "url",
#         "value": image_url,
#     },
#     "confidence": confidence,
#     "iou_threshold": iou_threshold,
#     "api_key": api_key,
# }
# res = requests.post(
#     f"http://localhost:9001/{workspace_id}/{model_id}",
#     json=infer_object_detection_payload,
# )
#
# predictions = res.json()
# ```
#
# Above, set your Roboflow workspace ID, model ID, and API key.
#
# - [Find your workspace and model ID](https://docs.roboflow.com/api-reference/workspace-and-project-ids?ref=blog.roboflow.com)
# - [Find your API key](https://docs.roboflow.com/api-reference/authentication?ref=blog.roboflow.com#retrieve-an-api-key)
#
# Also, set the URL of an image on which you want to run inference. This can be a local file.
#
# _To use your YOLOv5 model commercially with Inference, you will need a Roboflow Enterprise license, through which you gain a pass-through license for using YOLOv5. An enterprise license also grants you access to features like advanced device management, multi-model containers, auto-batch inference, and more._

# %% [markdown]
# ## 🏆 Congratulations
#
# ### Learning Resources
#
# Roboflow has produced many resources that you may find interesting as you advance your knowledge of computer vision:
#
# - [Roboflow Notebooks](https://github.com/roboflow/notebooks): A repository of over 20 notebooks that walk through how to train custom models with a range of model types, from YOLOv7 to SegFormer.
# - [Roboflow YouTube](https://www.youtube.com/c/Roboflow): Our library of videos featuring deep dives into the latest in computer vision, detailed tutorials that accompany our notebooks, and more.
# - [Roboflow Discuss](https://discuss.roboflow.com/): Have a question about how to do something on Roboflow? Ask your question on our discussion forum.
# - [Roboflow Models](https://roboflow.com): Learn about state-of-the-art models and their performance. Find links and tutorials to guide your learning.
#
# ### Convert data formats
#
# Roboflow provides free utilities to convert data between dozens of popular computer vision formats. Check out [Roboflow Formats](https://roboflow.com/formats) to find tutorials on how to convert data between formats in a few clicks.
#
# ### Connect computer vision to your project logic
#
# [Roboflow Templates](https://roboflow.com/templates) is a public gallery of code snippets that you can use to connect computer vision to your project logic. Code snippets range from sending emails after inference to measuring object distance between detections.
